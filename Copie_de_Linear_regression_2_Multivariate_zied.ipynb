# %% [markdown]
# <a href="https://colab.research.google.com/github/ziedjouini/machine-learning/blob/main/Copie_de_Linear_regression_2_Multivariate_zied.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Execute the code below

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
link = "https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather2019.csv"
df_weather = pd.read_csv(link)
df_weather
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    2019-01-01                  9                  4                 10
# 1    2019-01-02                  8                  5                 18
# 2    2019-01-03                  6                  0                 18
# 3    2019-01-04                  5                 -1                 15
# 4    2019-01-05                  6                 -1                  8
# ..          ...                ...                ...                ...
# 360  2019-12-27                 13                 10                 13
# 361  2019-12-28                 11                  5                 12
# 362  2019-12-29                  9                  2                 11
# 363  2019-12-30                 12                  4                  7
# 364  2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      WINDTEMP_MAX_C  WEATHER_CODE_MORNING  WEATHER_CODE_NOON  \
# 0                 3                   116                143
# 1                 3                   119                116
# 2                -4                   116                116
# 3                -4                   116                116
# 4                -2                   143                116
# ..              ...                   ...                ...
# 360               8                   119                143
# 361               4                   143                116
# 362               0                   116                116
# 363               4                   113                113
# 364               1                   113                143
#
#      WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  \
# 0                     176              0         1      5.1          very bad
# 1                     116              0         1      8.7          very bad
# 2                     116              0         1      8.7          very bad
# 3                     122              0         1      5.1          very bad
# 4                     116              0         1      8.7          very bad
# ..                    ...            ...       ...      ...               ...
# 360                   116              0         1      8.7  not good not bad
# 361                   116              0         1      6.9          very bad
# 362                   116              0         1      8.7          very bad
# 363                   113              0         1      8.7          very bad
# 364                   119              0         1      8.7          very bad
#
#      MONTH  DAY
# 0        1    1
# 1        1    2
# 2        1    3
# 3        1    4
# 4        1    5
# ..     ...  ...
# 360     12   27
# 361     12   28
# 362     12   29
# 363     12   30
# 364     12   31
#
# [365 rows x 24 columns]

# %% [markdown]
# # Multivariate linear regression with Scikit-Learn

# %% [markdown]
# The equation of an univariate linear regresion is a line : aX +b
#
# The equation of a multivariate linear regression with 2 variables is a plan : aW + bX + c
#
# The equation of a multivariate linear regression with n variables is a hyperplan : a1 X1 + a2 X2 + .... + an Xn + b

# %% [markdown]
# ## Let's start with 2 variables
# With Plotly express, show a [3D scatterplot ](https://plotly.com/python/plotly-express/#3d-coordinates)with :
# - X-axis : MAX temperature
# - Y-axis : MIN temperature
# - Z-axis : Sunhours

# %%
# Complete x, y and z in the script below:
px.scatter_3d(x =['MAX_TEMPERATURE_C'] , 
              y = ['MIN_TEMPERATURE_C'], 
              z= ['SUNHOUR'], 
              data_frame=df_weather)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b18ca2dd-5378-4a6c-baa0-c5657c927bed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b18ca2dd-5378-4a6c-baa0-c5657c927bed")) {                    Plotly.newPlot(                        "b18ca2dd-5378-4a6c-baa0-c5657c927bed",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":["MAX_TEMPERATURE_C"],"y":["MIN_TEMPERATURE_C"],"z":["SUNHOUR"],"type":"scatter3d"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0, ...

# %%
"""px.scatter_3d(x = , 
              y = , 
              z= , 
              data_frame=df_weather)"""
# Out:
# 'px.scatter_3d(x = , \n              y = , \n              z= , \n              data_frame=df_weather)'

# %%
import plotly.express as px
df = px.data.election()
fig = px.scatter_3d(df_weather, x="MAX_TEMPERATURE_C", y="MIN_TEMPERATURE_C", z="SUNHOUR")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7245be22-074a-44b3-bca5-41890e13db57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7245be22-074a-44b3-bca5-41890e13db57")) {                    Plotly.newPlot(                        "7245be22-074a-44b3-bca5-41890e13db57",                        [{"hovertemplate":"MAX_TEMPERATURE_C=%{x}<br>MIN_TEMPERATURE_C=%{y}<br>SUNHOUR=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":
,5.1,8.7,3.3,5.1,3.3,3.3,8.7,5.1,6.9,3.3,3.3,8.7,3.4,8.7,8.7,3.4,5.2,8.7,3.4,5.2,5.2,3.4,3.5,8.2,6.5,4.8,6.5,4.9,4.9,9.8,9.8,4.9,4.9,5.0,6.6,5.0,6.6,8.3,8.3,10.1,10.1,10.2,10.2,8.4,10.2,6.8,5.2,10.0,10.4,10.4,10.8,8.5,10.9,10.9,11.0,5.5,10.1,10.1,5.6,8.6,10.1,5.6,8.7,10.2,5.9,7.3,10.2,7.3,11.6,5.9,6.0,6.0,11.6,8.8,7.4,7.4,11.6,11.6,11.6,10.2,8.9,11.6,11.6,10.3,9.0,10.3,10.3,9.0,6.5,7.8,7.8,6.5,6.5,7.8,9.1,10.3,7.9,11.6,11.6,11.6,7.9,9.1,11.6,10.4,11.6,11.6,9.3,9.3,9.3,8.2,7.0,9.3,13.4,10.2,9.1,10.2,14.5,12.4,12.4,11.3,11.3,13.4,11.4,10.3,11.4,9.3,9.3,11.4,14.5,14.5,14.5,14.5,10.4,11.5,9.5,10.5,9.5,12.5,11.5,13.5,13.5,11.5,9.6,12.5,11.5,10.6,11.6,14.5,14.5,13.5,12.6,9.7,9.7,11.6,9.7,13.7,13.8,14.7,13.8,12.9,14.7,15.9,13.8,14.7,16.0,16.0,12.9,16.0,14.7,16.0,16.0,12.9,16.0,16.0,15.9,15.9,15.9,15.6,15.9,15.9,15.9,15.9,15.9,14.6,15.9,15.8,15.8,15.8,15.8,13.7,15.8,14.5,14.5,13.5,14.5,10.5,13.5,11.5,14.5,14.5,14.5,14.5,13.5,9.4,10.4,14.5,13.5,10.4,13.5,14.5,14.5,14.5,14.5,11.4,9.3,12.4,14.5,11.3,11.3,12.4,9.2,13.4,7.1,9.3,11.6,7.1,9.3,10.5,11.6,9.3,11.6,11.6,10.4,11.6,10.4,10.4,9.1,9.1,10.4,11.6,11.6,11.6,11.6,7.8,9.1,11.6,10.3,11.6,7.8,11.6,11.6,10.3,11.6,11.6,11.6,11.6,11.6,11.6,11.6,11.6,10.3,7.6,6.2,7.6,6.0,6.0,8.8,5.8,7.2,5.7,5.7, ...

# %% [markdown]
# Is it hard to read the 3D scatterplot ? You can move it with your mouse.

# %% [markdown]
# ### Let's predict
# You have to predict the MAX temperature from 2 variables :
# - MIN temperature
# - Sunhours
#
# Hey, it's the reason why X has 2 brackets and is uppercase and y has a simple bracket and is lowercase . It can take multiple variables (X) to predict only one target (y).
#
# **Remember to save the result of your prediction in a new column 'predict'.**

# %%
# Your code here :
X = 
y =

# %%
# Scikit-Learn can find the coefficients of the linear regression
from sklearn.linear_model import LinearRegression

# First of all, you have to define 2 series :
# X-axis : the correlated column, here it is Sunhours
X = df_weather[["MIN_TEMPERATURE_C", "SUNHOUR"]] 

# Y-axis : the column to predict, so MAX Temperature here
y = df_weather['MAX_TEMPERATURE_C'] 

# Hey, why is "X" in uppercase and "y" in lowercase ? That's a good point, we'll see that in the next quest. Now, you just have to use this.

# To train a machine learning model (here, it will find the equation of the linear regression), you just have launch the ".fit" method.
modelLR = LinearRegression().fit(X, y)

modelLR.score(X,y)
# Out:
# 0.8674787980774968

# %%
df_weather['predict']=modelLR.predict(df_weather[["MIN_TEMPERATURE_C", "SUNHOUR"]])
df_weather
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    2019-01-01                  9                  4                 10
# 1    2019-01-02                  8                  5                 18
# 2    2019-01-03                  6                  0                 18
# 3    2019-01-04                  5                 -1                 15
# 4    2019-01-05                  6                 -1                  8
# ..          ...                ...                ...                ...
# 360  2019-12-27                 13                 10                 13
# 361  2019-12-28                 11                  5                 12
# 362  2019-12-29                  9                  2                 11
# 363  2019-12-30                 12                  4                  7
# 364  2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      WEATHER_CODE_MORNING  WEATHER_CODE_NOON  WEATHER_CODE_EVENING  \
# 0                     116                143                   176
# 1                     119                116                   116
# 2                     116                116                   116
# 3                     116                116                   122
# 4                     143                116                   116
# ..                    ...                ...                   ...
# 360                   119                143                   116
# 361                   143                116                   116
# 362                   116                116                   116
# 363                   113                113                   113
# 364                   113                143                   119
#
#      TOTAL_SNOW_MM  UV_INDEX  SUNHOUR           OPINION  MONTH  DAY    predict
# 0                0         1      5.1          very bad      1    1   8.980922
# 1                0         1      8.7          very bad      1    2  12.353602
# 2                0         1      8.7          very bad      1    3   7.410233
# 3                0         1      5.1          very bad      1    4   4.037552
# 4                0         1      8.7          very bad      1    5   6.421559
# ..             ...       ...      ...               ...    ...  ...        ...
# 360              0         1      8.7  not good not bad     12   27  17.296971
# 361              0         1      6.9          very bad     12   28  11.161599
# 362              0         1      8.7          very bad     12   29   9.387580
# 363              0         1      8.7          very bad     12   30  11.364928
# 364              0         1      8.7          very bad     12   31  11.364928
#
# [365 rows x 25 columns]

# %%
"""from sklearn.linear_model import LinearRegression

X = df[["MIN_TEMPERATURE_C", "SUNHOUR"]]

y = df['MAX_TEMPERATURE_C']


# We train a "model" with "fit" function. This model will store coefficients after training.

model = LinearRegression().fit(X, y)"""
# Out:
# 'from sklearn.linear_model import LinearRegression\n\nX = df[["MIN_TEMPERATURE_C", "SUNHOUR"]]\n\ny = df[\'MAX_TEMPERATURE_C\']\n\n\n# We train a "model" with "fit" function. This model will store coefficients after training.\n\nmodel = LinearRegression().fit(X, y)'

# %% [markdown]
# ### Let's visualize
# With Plotly express, show a 3D scatterplot with :
#
# - X-axis : your new 'predict' column
# - Y-axis : MIN temperature
# - Z-axis : Sunhours

# %%
# Your code here :

# %%
import plotly.express as px
df = px.data.election()
fig = px.scatter_3d(df_weather, x="predict", y="MIN_TEMPERATURE_C", z="SUNHOUR")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b4aa0830-fcb1-4f2e-90c6-7a02222e4840" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4aa0830-fcb1-4f2e-90c6-7a02222e4840")) {                    Plotly.newPlot(                        "b4aa0830-fcb1-4f2e-90c6-7a02222e4840",                        [{"hovertemplate":"predict=%{x}<br>MIN_TEMPERATURE_C=%{y}<br>SUNHOUR=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":
# - X-axis : Date
# - Y-axis : MAX temperatures in blue dots and 'predict2' in orange dots
#
# Expected result:
#
# ![Capture d’écran 2020-11-03 à 13.58.13.png](data:image/png;base64,...)

# %%
# Your code here :

# %%
from sklearn.linear_model import LinearRegression

X = df_weather[['MIN_TEMPERATURE_C','SUNHOUR',"WINDSPEED_MAX_KMH","TEMPERATURE_NOON_C"]]

y = df_weather['MAX_TEMPERATURE_C']


# We train a "model" with "fit" function. This model will store coefficients after training.

model = LinearRegression().fit(X, y)

# %%
df_weather['predict2']=model.predict(X)
df_weather
# Out:
#            DATE  MAX_TEMPERATURE_C  MIN_TEMPERATURE_C  WINDSPEED_MAX_KMH  \
# 0    2019-01-01                  9                  4                 10
# 1    2019-01-02                  8                  5                 18
# 2    2019-01-03                  6                  0                 18
# 3    2019-01-04                  5                 -1                 15
# 4    2019-01-05                  6                 -1                  8
# ..          ...                ...                ...                ...
# 360  2019-12-27                 13                 10                 13
# 361  2019-12-28                 11                  5                 12
# 362  2019-12-29                  9                  2                 11
# 363  2019-12-30                 12                  4                  7
# 364  2019-12-31                 10                  4                 13
#
#      TEMPERATURE_MORNING_C  TEMPERATURE_NOON_C  TEMPERATURE_EVENING_C  \
# 0                        4                   7                      8
# 1                        7                   7                      5
# 2                        0                   4                      3
# 3                       -1                   4                      3
# 4                       -1                   4                      3
# ..                     ...                 ...                    ...
# 360                     10                  12                     11
# 361                      7                   8                      8
# 362                      3                   6                      7
# 363                      5                   9                      9
# 364                      4                   7                      9
#
#      PRECIP_TOTAL_DAY_MM  HUMIDITY_MAX_PERCENT  VISIBILITY_AVG_KM  ...  \
# 0                    0.2                    94              9.000  ...
# 1                    0.0                    90              9.000  ...
# 2                    0.0                    88             10.000  ...
# 3                    0.0                    91             10.000  ...
# 4                    0.0                    91              8.000  ...
# ..                   ...                   ...                ...  ...
# 360                  0.0                    96              7.375  ...
# 361                  0.0                    93              7.625  ...
# 362                  0.0                    86             10.000  ...
# 363                  0.0                    61             10.000  ...
# 364                  0.1                    94              9.000  ...
#
#      WEATHER_CODE_NOON  WEATHER_CODE_EVENING  TOTAL_SNOW_MM  UV_INDEX  \
# 0                  143                   176              0         1
# 1                  116                   116              0         1
# 2                  116                   116              0         1
# 3                  116                   122              0         1
# 4                  116                   116              0         1
# ..                 ...                   ...            ...       ...
# 360                143                   116              0         1
# 361                116                   116              0         1
# 362                116                   116              0         1
# 363                113                   113              0         1
# 364                143                   119              0         1
#
#      SUNHOUR           OPINION  MONTH  DAY    predict   predict2
# 0        5.1          very bad      1    1   8.980922   8.825213
# 1        8.7          very bad      1    2  12.353602   9.203829
# 2        8.7          very bad      1    3   7.410233   5.761820
# 3        5.1          very bad      1    4   4.037552   5.095211
# 4        8.7          very bad      1    5   6.421559   6.124417
# ..       ...               ...    ...  ...        ...        ...
# 360      8.7  not good not bad     12   27  17.296971  14.517207
# 361      6.9          very bad     12   28  11.161599  10.028101
# 362      8.7          very bad     12   29   9.387580   8.175164
# 363      8.7          very bad     12   30  11.364928  11.207401
# 364      8.7          very bad     12   31  11.364928   9.278433
#
# [365 rows x 26 columns]

# %%
from datetime import datetime
df_weather["DATE"]=pd.to_datetime(df_weather["DATE"])

# %%
plt.scatter(x=df_weather['DATE'], y=df_weather['MAX_TEMPERATURE_C'])
plt.scatter(x=df_weather['DATE'], y=df_weather['predict'])

# %%
plt.scatter(x=df_weather['DATE'], y=df_weather['MAX_TEMPERATURE_C'])
plt.scatter(x=df_weather['DATE'], y=df_weather['predict2'])

# %%
print("coefficient :",model.coef_)
# Out:
# coefficient : [ 0.2133886   0.17389325 -0.05759855  0.79168862]

# %%
print("interception :",model.intercept_)
# Out:
# interception : 2.1189679065211955

# %%
for i, j in zip (X.columns, model.coef_):

  print(i,j)
# Out:
# MIN_TEMPERATURE_C 0.2133885978216751
# SUNHOUR 0.173893250097644
# WINDSPEED_MAX_KMH -0.05759855171966026
# TEMPERATURE_NOON_C 0.7916886214421918

# %% [markdown]
# You can read coefficient for each column with the attribute `.coef_`. Which column has the biggest coefficient ?

# %%
# Your code here :

# %%
my_dict={}
for col , coef in zip(X.columns, model.coef_):
  my_dict[col] = coef

key= ''
value =  max(my_dict.values())
for k,v in my_dict.items():
  if v == value:
    key = k




print(f'the bisggest coefficient is : {key , value}')
# Out:
# the bisggest coefficient is : ('TEMPERATURE_NOON_C', 0.7916886214421918)
